# %% [markdown]
#   # **My first markdown cell in Jupyter**

# %%
greeting = "Hello World"
print(greeting)
# Out:
# Hello World

# %%
#Mount Google Drive
from google.colab import drive
from pprint import pprint
drive.mount("/content/drive", force_remount=True)

#Sanity Check on mount
import os
print("Contents of my Google Drive")


#print ( os.listdir("/content/drive/MyDrive") [:10]     )
pprint(os.listdir("/content/drive/MyDrive")[:10])
# Out:
# Mounted at /content/drive
# Contents of my Google Drive
# ['Accident Report.gdoc',
#  'God essay.gdoc',
#  'get it get it.docx.gdoc',
#  'ID LIST for HIST 355.gdoc',
#  'Midterm Review, HIST 447.gdoc',
#  'projectstat4.gsheet',
#  'google docs test.gsheet',
#  'j.1745-4549.1997.tb00792.x.pdf',
#  'bank shot',
#  'jqas.2011.7.1.1299.pdf']

# %%
# %cd /content/drive/MyDrive

# !git clone https://github.com/Toyin-Fadiran/jupyter-exploration.git
# Out:
# /content/drive/MyDrive
# Cloning into 'jupyter-exploration'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 4.27 KiB | 485.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls -la jupyter-exploration/
# !pwd
# %cd jupyter-exploration/
# Out:
# total 5
# drwx------ 8 root root 4096 Jun  8 20:08 .git
# -rw------- 1 root root  745 Jun  8 20:08 README.md
# /content/drive/MyDrive
# /content/drive/MyDrive/jupyter-exploration

# %%
# !ls
# Out:
# README.md

# %%
import os
os.chdir("/content/drive/MyDrive/jupyter-exploration")

# !pwd
# !ls -la
# !cd ..
# !pwd
# Out:
# /content/drive/MyDrive/jupyter-exploration
# total 10
# drwx------ 2 root root 4096 Jun  8 20:08 .git
# -rw------- 1 root root 4803 Jun  8 20:20 My_First_Notebook.ipynb
# -rw------- 1 root root  745 Jun  8 20:08 README.md
# /content/drive/MyDrive/jupyter-exploration

# %%
# %cd /content/drive/MyDrive/jupyter-exploration

# Configure Git (do this once per session)
# !git config --global user.email "toyin.fadiran@gmail.com
# !git config --global user.name "Toyin Fadiran"
# Add your changes
# !git add .
# Commit with a message
# !git commit -m "Added first juypter Notebook"
# Push to GitHub (you will need authentication)
# !git push
# Out:
# /content/drive/MyDrive/jupyter-exploration
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
